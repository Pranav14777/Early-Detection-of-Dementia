# %%
import numpy as np
import pandas as pd
import re
from glob import glob

# %%
path = pd.DataFrame(glob('/Users/hirthikprasaad/Downloads/Pitt/Control/cookie/*'),columns=['locations'])
path1 = pd.DataFrame(glob('/Users/hirthikprasaad/Downloads/Pitt/Dementia/sentence/*'),columns=['locations'])

# %%
m = len(path['locations'])
path['locations']
# Out:
# 0      /Users/hirthikprasaad/Downloads/Pitt/Control/c...
# 1      /Users/hirthikprasaad/Downloads/Pitt/Control/c...
# 2      /Users/hirthikprasaad/Downloads/Pitt/Control/c...
# 3      /Users/hirthikprasaad/Downloads/Pitt/Control/c...
# 4      /Users/hirthikprasaad/Downloads/Pitt/Control/c...
#                              ...
# 242    /Users/hirthikprasaad/Downloads/Pitt/Control/c...
# 243    /Users/hirthikprasaad/Downloads/Pitt/Control/c...
# 244    /Users/hirthikprasaad/Downloads/Pitt/Control/c...
# 245    /Users/hirthikprasaad/Downloads/Pitt/Control/c...
# 246    /Users/hirthikprasaad/Downloads/Pitt/Control/c...
# Name: locations, Length: 247, dtype: object

# %%
m1 = len(path1['locations'])
path1['locations']
# Out:
# 0      /Users/hirthikprasaad/Downloads/Pitt/Dementia/...
# 1      /Users/hirthikprasaad/Downloads/Pitt/Dementia/...
# 2      /Users/hirthikprasaad/Downloads/Pitt/Dementia/...
# 3      /Users/hirthikprasaad/Downloads/Pitt/Dementia/...
# 4      /Users/hirthikprasaad/Downloads/Pitt/Dementia/...
#                              ...
# 305    /Users/hirthikprasaad/Downloads/Pitt/Dementia/...
# 306    /Users/hirthikprasaad/Downloads/Pitt/Dementia/...
# 307    /Users/hirthikprasaad/Downloads/Pitt/Dementia/...
# 308    /Users/hirthikprasaad/Downloads/Pitt/Dementia/...
# 309    /Users/hirthikprasaad/Downloads/Pitt/Dementia/...
# Name: locations, Length: 310, dtype: object

# %%
filelines =[]
filelines1 = []

# %%
for i in range(m):
    myfile = open(path['locations'].iloc[i],"r")
    txt = myfile.read()
#     print(txt)
    filelines.append(txt.split('\n'))

# %%
for i in range(m1):
    myfile1 = open(path1['locations'].iloc[i],"r")
    txt1 = myfile.read()
#     print(txt)
    filelines1.append(txt1.split('\n'))

# %%
# index = filelines.index(line[0] == '*')
index = []
sorts = []
indexD = []
sortsD = []

# %%
# for i in range(m):
#     myfile = open(path['locations'].iloc[i],"r")
#     txt = myfile.read()
# #     print(txt)
#     filelines.append(txt.split('\n'))
final =[]
final1 = []

# %%
for line in filelines:
    for i in line:
        final.append(i)

# %%
for line1 in filelines1:
    for i1 in line:
        final1.append(i1)

# %%
while('' in final):
    final.remove('')

# %%
while('' in final1):
    final1.remove('')

# %%
final
# Out:
# ['@UTF8',
#  '@PID:\t11312/t-00002293-1',
#  '@Begin',
#  '@Languages:\teng',
#  '@Participants:\tPAR Participant, INV Investigator',
#  '@ID:\teng|Pitt|PAR|68;|female|Control||Participant|28||',
#  '@ID:\teng|Pitt|INV|||||Investigator|||',
#  '@Media:\t138-1, audio',
#  '@G:\tCookie',
#  '*PAR:\tokay . [+ exc] \x150_2129\x15',
#  '%mor:\tco|okay .',
#  '%gra:\t1|0|INCROOT 2|1|PUNCT',
#  "*PAR:\tthere's a cookie jar on the shelf . \x152129_5471\x15",
#  '%mor:\tpro:exist|there~cop|be&3S det:art|a n|cookie n|jar prep|on',
#  '\tdet:art|the n|shelf .',
#  '%gra:\t1|2|SUBJ 2|0|ROOT 3|5|DET 4|5|MOD 5|2|PRED 6|5|NJCT 7|8|DET 8|6|POBJ',
#  '\t9|2|PUNCT',
#  "*PAR:\tand the little boy's up on a stool . \x155471_7249\x15",
#  '%mor:\tcoord|and det:art|the adj|little n|boy~cop|be&3S adv|up prep|on',
#  '\tdet:art|a n|stool .',
#  '%gra:\t1|5|LINK 2|4|DET 3|4|MOD 4|5|SUBJ 5|0|ROOT 6|5|JCT 7|5|JCT 8|9|DET',
#  '\t9|7|POBJ 10|5|PUNCT',
# ...

# %%
    for lines in final:
        if lines[0] == '*' and lines[1] == 'P':
            index.append(final.index(lines))
            new_line= re.sub(r"[^a-zA-Z.'?,@]"," ",lines).replace("exc","").replace("gram","")
            words = new_line.split()
            s = " ".join(words[1:])
            sorts.append(s)
        
        
        
            
                
                
              
                
            
       
      
        
            
            
#             print(index)
            
            
               
        
            
               
                
                 
        
    
    
   
    
            
         
            
            
         
         
            
           

    
   

        
        
        
        
#         if line[index+1] == '\t':
#             new_line1= re.sub(r"[^a-zA-Z.'?,@]"," ",line).replace("exc","")
#             words1 = new_line.split()
#             s1 = " ".join(words1[1:])
#             print(s1)

# %%
    for lines1 in final1:
        if lines1[0] == '*' and lines1[1] == 'P':
            indexD.append(final1.index(lines1))
            new_line1= re.sub(r"[^a-zA-Z.'?,@]"," ",lines1).replace("exc","").replace("gram","")
            words1 = new_line1.split()
            sd = " ".join(words1[1:])
            sortsD.append(sd)

# %%
index
# Out:
# [9,
#  12,
#  17,
#  22,
#  25,
#  28,
#  33,
#  36,
#  41,
#  46,
#  49,
#  54,
#  63,
#  74,
#  77,
#  83,
#  99,
#  102,
#  105,
#  110,
#  115,
#  118,
#  123,
#  128,
#  160,
#  164,
#  172,
#  176,
#  179,
#  183,
#  186,
#  189,
#  192,
#  195,
#  200,
#  213,
#  216,
#  226,
#  231,
#  243,
#  253,
#  262,
#  265,
#  277,
#  282,
#  288,
#  298,
#  306,
#  311,
#  316,
#  326,
#  332,
#  347,
#  353,
#  374,
#  384,
#  389,
#  392,
#  395,
#  400,
#  403,
#  411,
#  417,
#  437,
#  445,
#  450,
#  458,
#  463,
#  467,
#  473,
#  476,
#  484,
#  487,
#  496,
#  518,
#  530,
#  533,
#  540,
#  547,
#  554,
#  557,
#  560,
#  563,
#  566,
#  569,
#  601,
#  606,
#  611,
#  616,
#  626,
#  629,
#  637,
#  648,
#  672,
#  680,
#  684,
#  689,
#  692,
#  695,
#  698,
#  703,
#  708,
#  711,
#  714,
#  719,
#  723,
#  751,
#  754,
#  758,
#  761,
#  766,
#  771,
#  776,
#  786,
#  789,
#  795,
#  802,
#  825,
#  828,
#  840,
#  847,
#  850,
#  853,
#  856,
#  862,
#  878,
#  881,
# ...

# %%
index1 = []
sorts1 = []
indexD1 = []
sortsD1 = []

# %%
    for i in range(len(indexD)):
        if final1[indexD[i]+1][0] == '\t':
            new_line2D= re.sub(r"[^a-zA-Z.'?,@]"," ",final1[indexD[i]]).replace("exc","")
            words2D = new_line2D.split()
            s2D = " ".join(words2D[1:])
            indexD1.append(sortsD.index(s2D))
            
            
            
                               
                               
            
            
            new_line1D= re.sub(r"[^a-zA-Z.'?,@]"," ",final1[indexD[i]+1]).replace("exc","")
           
            
            
             
            words1D = new_line1D.split()
            s1D = " ".join(words1D[1:])
            sortsD1.append(s1D)
            print(s1D)
# Out:
# for the cookies .
# and another part of the house maybe a garage .
# for the cookies .
# and another part of the house maybe a garage .
# for the cookies .
# and another part of the house maybe a garage .
# for the cookies .
# and another part of the house maybe a garage .
# for the cookies .
# and another part of the house maybe a garage .
# for the cookies .
# and another part of the house maybe a garage .
# for the cookies .
# and another part of the house maybe a garage .
# for the cookies .
# and another part of the house maybe a garage .
# for the cookies .
# and another part of the house maybe a garage .
# for the cookies .
# and another part of the house maybe a garage .
# for the cookies .
# and another part of the house maybe a garage .
# for the cookies .
# and another part of the house maybe a garage .
# for the cookies .
# and another part of the house maybe a garage .
# for the cookies .
# and another part of the house maybe a garage .
# for the cookies .
# ...

# %%
for i in range(len(index)):
        if final[index[i]+1][0] == '\t':
            new_line2= re.sub(r"[^a-zA-Z.'?,@]"," ",final[index[i]]).replace("exc","")
            words2 = new_line2.split()
            s2 = " ".join(words2[1:])
            index1.append(sorts.index(s2))
            
            
            
                               
                               
            
            
            new_line1= re.sub(r"[^a-zA-Z.'?,@]"," ",final[index[i]+1]).replace("exc","")
           
            
            
             
            words1 = new_line1.split()
            s1 = " ".join(words1[1:])
            sorts1.append(s1)
            print(s1)
# Out:
# and a dri uh a walk way away from the house .
# with uh a tree, that there are there are curtains on the
# of a cookie jar .
# left hand to reach down to give to his si .
# finger of her right hand pointed upward up close to her mouth
# be quiet because the stool is um going to fall over .
# uh running shoes with pompoms on them .
# girl is wearing uh looks as if its sole is thicker than the
# sink .
# as if she has something else .
# that's behind her the plate in her left hand .
# left of the back of the house .
# gram
# is standing with her foot in the water but not where it
# cookie jar .
# her hand up to her mouth .
# not paying any attention that the water is spilling all over
# jar .
# over .
# .
# on laughs .
# mother to know what they were up to .
# cut .
# was goin g on the floor and she's gonna get wet or is wet .
#
# reaching for the cookie to give to her while the the uh
# .
# to her mouth and the one arm extended up uh looking up at the
# lower hand the left hand .
# ...

# %%
index1
# Out:
# [11,
#  12,
#  25,
#  36,
#  38,
#  39,
#  40,
#  42,
#  44,
#  45,
#  46,
#  49,
#  50,
#  51,
#  63,
#  65,
#  74,
#  76,
#  77,
#  78,
#  84,
#  88,
#  90,
#  91,
#  112,
#  118,
#  119,
#  126,
#  129,
#  132,
#  133,
#  140,
#  141,
#  144,
#  145,
#  146,
#  147,
#  157,
#  163,
#  165,
#  168,
#  171,
#  196,
#  203,
#  206,
#  215,
#  224,
#  225,
#  229,
#  230,
#  236,
#  237,
#  238,
#  239,
#  240,
#  241,
#  244,
#  247,
#  248,
#  253,
#  260,
#  263,
#  267,
#  272,
#  280,
#  283,
#  284,
#  294,
#  295,
#  298,
#  303,
#  312,
#  318,
#  319,
#  324,
#  328,
#  334,
#  339,
#  342,
#  343,
#  344,
#  347,
#  350,
#  351,
#  353,
#  356,
#  362,
#  363,
#  364,
#  366,
#  369,
#  373,
#  375,
#  378,
#  381,
#  383,
#  387,
#  390,
#  391,
#  401,
#  402,
#  408,
#  416,
#  425,
#  427,
#  428,
#  440,
#  441,
#  442,
#  443,
#  444,
#  457,
#  462,
#  466,
#  467,
#  468,
#  472,
#  478,
#  483,
#  484,
#  486,
#  490,
#  492,
#  493,
#  501,
#  504,
#  531,
#  536,
# ...

# %%
for i in range(len(index1)):
    sorts[index1[i]] += " "+sorts1[i]

# %%
for i in range(len(indexD1)):
    sortsD[indexD1[i]] += " "+sortsD1[i]

# %%
sorts
# Out:
# ['okay .',
#  "there's a cookie jar on the shelf .",
#  "and the little boy's up on a stool .",
#  "and the stool is about to uh fall he's about to fall .",
#  "the stool's about to turn over .",
#  "little girl in the picture's reaching for the cookie .",
#  'mother is washing dishes .',
#  "the water's uh running and running over onto the floor .",
#  'she she has a plate in her hand and a towel .',
#  "she's drying a plate .",
#  'two cups are sitting on a counter and also a plate .',
#  'you can see out through the kitchen window to another part of the and a dri uh a walk way away from the house .',
#  'you can see a window across in the other part of the house, the with uh a tree, that there are there are curtains on the',
#  "... I think that's ...",
#  'did I cover it all ?',
#  'yeah .',
#  'the kids are in the cookies .',
#  'the stool is falling over .',
#  "the mother's spilling the water and also drying the dishes .",
#  'and the wind might be blowing the curtains .',
# ...

# %%
df=pd.DataFrame(sorts,columns=["message"])

# %%
df1=pd.DataFrame(sortsD,columns=["message"])

# %%
labelD =[]
for i in range(len(sortsD)):
    labelD.append("positive")

# %%
len(sorts)
label =[]
for i in range(len(sorts)):
    label.append("neagtive")

# %%
len(label)
# Out:
# 3228

# %%
df['label']  =label

# %%
df1['label'] = labelD

# %%
df
# Out:
#                                                 message     label
# 0                                                okay .  neagtive
# 1                   there's a cookie jar on the shelf .  neagtive
# 2                  and the little boy's up on a stool .  neagtive
# 3     and the stool is about to uh fall he's about t...  neagtive
# 4                      the stool's about to turn over .  neagtive
# ...                                                 ...       ...
# 3223  the through the window we can see a walk way t...  neagtive
# 3224  there's two sau two cups and a plate on a kitc...  neagtive
# 3225                        .. the cookie jar is full .  neagtive
# 3226  and the boy has the lid off and has one cookie...  neagtive
# 3227                                        that's it .  neagtive
#
# [3228 rows x 2 columns]

# %%
df1
# Out:
#                                                 message     label
# 0                 tell you everything that's going on ?  positive
# 1     there's a little girl asking her brother for a...  positive
# 2     he is on a s step he's on a high step stool re...  positive
# 3           and the stool is going out from under him .  positive
# 4                                 he is going to fall .  positive
# ...                                                 ...       ...
# 4025  the through the window we can see a walk way t...  positive
# 4026  there's two sau two cups and a plate on a kitc...  positive
# 4027                        .. the cookie jar is full .  positive
# 4028  and the boy has the lid off and has one cookie...  positive
# 4029                                        that's it .  positive
#
# [4030 rows x 2 columns]

# %%
result= pd.concat([df, df1])

# %%
result
# Out:
#                                                 message     label
# 0                                                okay .  neagtive
# 1                   there's a cookie jar on the shelf .  neagtive
# 2                  and the little boy's up on a stool .  neagtive
# 3     and the stool is about to uh fall he's about t...  neagtive
# 4                      the stool's about to turn over .  neagtive
# ...                                                 ...       ...
# 4025  the through the window we can see a walk way t...  positive
# 4026  there's two sau two cups and a plate on a kitc...  positive
# 4027                        .. the cookie jar is full .  positive
# 4028  and the boy has the lid off and has one cookie...  positive
# 4029                                        that's it .  positive
#
# [7258 rows x 2 columns]

# %%
result = result.reset_index(drop=True)

# %%
ind = result.index

# %%
result['+AD']=result['label'].apply(lambda x: 1 if x=='positive' else 0)
result.sample()
# Out:
#                    message     label  +AD
# 2213  and . the curtains .  neagtive    0

# %%
# from sklearn.model_selection import train_test_split
# X_train, X_test, y_train, y_test = train_test_split(result['message'],result['+AD'], stratify=result['+AD'])
# X_train.head(4)

# %%
result['message'].str.len().hist()
# Out:
# <AxesSubplot:>

# %%
result['message'].str.split().\
   apply(lambda x : [len(i) for i in x]). \
   map(lambda x: np.mean(x)).hist()
# Out:
# <AxesSubplot:>

# %%
import nltk
from nltk.corpus import stopwords
nltk.download('stopwords')
stop=set(stopwords.words('english'))
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/hirthikprasaad/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
# pip install nltk
import matplotlib.pyplot as plt

# %%
corpus=[]
new= result['message'].str.split()
new=new.values.tolist()
corpus=[word for i in new for word in i]

from collections import defaultdict
dic=defaultdict(int)
for word in corpus:
    if word in stop:
        dic[word]+=1

# %%
top=sorted(dic.items(), key=lambda x:x[1],reverse=True)[:10] 
x,y=zip(*top)
plt.bar(x,y)
# Out:
# <BarContainer object of 10 artists>

# %%
from collections import  Counter
import seaborn as sns
counter=Counter(corpus)
most=counter.most_common()

x, y= [], []
for word,count in most[:40]:
    if (word not in stop):
        x.append(word)
        y.append(count)
        
sns.barplot(x=y,y=x)
# Out:
# <AxesSubplot:>

# %%
from wordcloud import WordCloud, STOPWORDS
stopwords = set(STOPWORDS)

def show_wordcloud(data):
    wordcloud = WordCloud(
        background_color='white',
        stopwords=stopwords,
        max_words=100,
        max_font_size=30,
        scale=3,
        random_state=1)
   
    wordcloud=wordcloud.generate(str(data))

    fig = plt.figure(1, figsize=(12, 12))
    plt.axis('off')

    plt.imshow(wordcloud)
    plt.show()

show_wordcloud(corpus)

# %%
import numpy as np
from keras.preprocessing import sequence
from keras.models import Sequential
from keras.layers import Dense, Dropout, Embedding, LSTM, Bidirectional

# %%
n_unique_words = 10000 
maxlen = 200
batch_size = 128

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(result['message'],result['+AD'],random_state=104, 
                                   test_size=0.25)

# %%
x_train = sequence.pad_sequences(x_train, maxlen=maxlen)
x_test = sequence.pad_sequences(x_test, maxlen=maxlen)
y_train = np.array(y_train)
y_test = np.array(y_test)
# Out:
# 0                                  [101, 3100, 1012, 102]
# 1       [101, 2045, 1005, 1055, 1037, 17387, 15723, 20...
# 2       [101, 1998, 1996, 2210, 2879, 1005, 1055, 2039...
# 3       [101, 1998, 1996, 14708, 2003, 2055, 2000, 791...
# 4       [101, 1996, 14708, 1005, 1055, 2055, 2000, 273...
#                               ...
# 7253    [101, 1996, 2083, 1996, 3332, 2057, 2064, 2156...
# 7254    [101, 2045, 1005, 1055, 2048, 7842, 2226, 2048...
# 7255    [101, 1012, 1012, 1996, 17387, 15723, 2003, 24...
# 7256    [101, 1998, 1996, 2879, 2038, 1996, 11876, 212...
# 7257             [101, 2008, 1005, 1055, 2009, 1012, 102]
# Name: message, Length: 7258, dtype: object

# %%
model = Sequential()
model.add(Embedding(n_unique_words, 128, input_length=maxlen))
model.add(Bidirectional(LSTM(64)))
model.add(Dropout(0.5))
model.add(Dense(1, activation='sigmoid'))
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
 history=model.fit(x_train, y_train,
           batch_size=batch_size,
           epochs=12,
           validation_data=[x_test, y_test])
print(history.history['loss'])
print(history.history['accuracy'])
# Out:
# (7258, 512)

# %%
from matplotlib import pyplot
pyplot.plot(history.history['loss'])
pyplot.plot(history.history['accuracy'])
pyplot.title('model loss vs accuracy')
pyplot.xlabel('epoch')
pyplot.legend(['loss', 'accuracy'], loc='upper right')
pyplot.show()
# Out:
# (7258, 512)

# %%
y_pred = model.predict(x_test)

# %%
from sklearn.metrics import classification_report
classification_report(y_test, y_pred)

# %%
from sklearn.metrics import confusion_matrix

# %%
confusion_matrix(y_test, y_pred)
